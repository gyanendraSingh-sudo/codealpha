# %%
import pandas as pd
import numpy as np

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)

# %%
from gensim.models import Word2Vec

# %%
df=pd.read_csv('tweet_sentiment.csv')

# %%
df.head()
# Out:
#                            tweet sentiment
# 0      The event starts at 5 PM.   neutral
# 1    I hate how this turned out.  negative
# 2          Fantastic experience!  positive
# 3          Fantastic experience!  positive
# 4  This is the worst thing ever!  negative

# %%
df.tail()
# Out:
#                             tweet sentiment
# 995          It’s cloudy outside.   neutral
# 996        Great job by the team!  positive
# 997  I'm so happy about the news!  positive
# 998       It ruined my whole day.  negative
# 999   I'm sick of this happening.  negative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      1000 non-null   object
#  1   sentiment  1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
df.describe()
# Out:
#                         tweet sentiment
# count                    1000      1000
# unique                     17         3
# top     Fantastic experience!  positive
# freq                       71       396

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc=df['tweet'].apply(lambda x: nlp(x))

# %%
def preprocess(texts):
  tokens=[token.text for token in texts if not token.is_stop and not token.is_punct]
  return tokens

# %%
final=doc.apply(lambda x: preprocess(x))

# %%
final_text=final.apply(lambda x: ' '.join(x))

# %%
model = Word2Vec(final_text, vector_size=100, window=5, min_count=1, workers=4)
# Out:
# WARNING:gensim.models.word2vec:Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.

# %%
max_len = 100
X = []

for sentence in final_text:
    sentence_vecs = []
    for word in sentence:
        if word in model.wv:
            sentence_vecs.append(model.wv[word])
    # Pad to fixed length
    while len(sentence_vecs) < max_len:
        sentence_vecs.append(np.zeros(model.vector_size))
    sentence_vecs = sentence_vecs[:max_len]  # truncate if longer
    X.append(sentence_vecs)

X = np.array(X)  # Shape: (num_sentences, 100, 100)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
y=le.fit_transform(df['sentiment'])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dropout, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 1000
max_length = 10
embedding_dim = 64

# Tokenization
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(final_text)
sequences = tokenizer.texts_to_sequences(final_text)
padded = pad_sequences(sequences, maxlen=max_length, padding='post')
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length),
    LSTM(64),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Use 'softmax' for multi-class
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(sequences,y,test_size=0.2,random_state=42)

# %%
x_train = pad_sequences(x_train, padding='post', maxlen=10)

# %%
model.fit(x_train,y_train,epochs=25)
# Out:
# Epoch 1/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3199 - loss: 0.3422
# Epoch 2/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3325 - loss: -0.9111
# Epoch 3/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4737 - loss: -3.2478
# Epoch 4/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6168 - loss: -5.1585
# Epoch 5/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6311 - loss: -5.8227
# Epoch 6/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5958 - loss: -7.2038
# Epoch 7/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6253 - loss: -7.4820
# Epoch 8/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6146 - loss: -8.3143
# Epoch 9/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5913 - loss: -9.5912
# Epoch 10/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5949 - loss: -10.2577
# Epoch 11/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6061 - loss: -10.7439
# Epoch 12/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5949 - loss: -11.7393
# Epoch 13/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5973 - loss: -12.1089
# Epoch 14/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5821 - loss: -13.3964
# Epoch 15/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5965 - loss: -13.6375
# Epoch 16/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5938 - loss: -14.2574
# Epoch 17/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5876 - loss: -15.3052
# Epoch 18/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6061 - loss: -15.0315
# Epoch 19/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5832 - loss: -16.8160
# Epoch 20/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6219 - loss: -15.8687
# Epoch 21/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5974 - loss: -17.6276
# Epoch 22/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5943 - loss: -18.5109
# Epoch 23/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5756 - loss: -19.6225
# Epoch 24/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6006 - loss: -19.2227
# Epoch 25/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6236 - loss: -18.8402

# %%
x_test=pad_sequences(x_test, padding='post', maxlen=10)

# %%
y_pred = model.predict(x_test)
print("Predicted Output:", y_pred)
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78d3d8cdea20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted Output: [[1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [9.6328586e-05]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [8.3381135e-05]
#  [9.2849201e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [9.2849201e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [9.2849201e-05]
#  [9.6328586e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [9.6328586e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [7.1227543e-05]
#  [9.6328586e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.7241286e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [9.2849201e-05]
#  [7.1227543e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [8.7241286e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [9.2849201e-05]
#  [8.8459346e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [7.1227543e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [8.8459172e-05]
#  [9.6328586e-05]
#  [1.0000000e+00]
#  [9.2849201e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.7241286e-05]
#  [8.7241286e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [8.3381135e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [7.1227543e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [9.2849201e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.7241133e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [9.6328586e-05]
#  [7.1227543e-05]
#  [7.1227543e-05]
#  [8.7241286e-05]
#  [9.6328586e-05]
#  [1.0000000e+00]
#  [9.2849201e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [1.0000000e+00]
#  [8.8459172e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [1.0000000e+00]
#  [9.2849201e-05]
#  [7.1227543e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [9.2849201e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [8.3381135e-05]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]]
